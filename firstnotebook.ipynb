# %%
# this was my first print world
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# this was my first print world

# %%
#pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    --------- ------------------------------ 2.4/9.8 MB 12.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.5/9.8 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 16.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ----------------- ---------------------- 5.5/12.7 MB 28.2 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.7 MB 29.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 27.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
# ...

# %%
import pandas as pd

data  = pd.read_csv("C:/Users/student/Documents/imc/MSc/Principles and tools in bilogical data analytics I/primates_diet_genesymbols.tsv", sep="\t", header=0)

print(data)
# Out:
#       Gene.Symbol  ChimpanzeeDiet1.1  ChimpanzeeDiet1.2  ChimpanzeeDiet1.3  \
# 0           Copg1                 57                 73                 83
# 1        Atp6v0d1                283                313                359
# 2          Golga7                233                213                205
# 3            Psph                 13                 13                 13
# 4         Trappc4                 56                 58                 67
# ...           ...                ...                ...                ...
# 43009        Tfrc                  6                  7                  6
# 43010        Tfrc                  6                  7                  7
# 43011         NaN                  6                  6                  6
# 43012         NaN                  7                  8                  7
# 43013         NaN                  7                  6                  6
#
#        ChimpanzeeDiet2.1  ChimpanzeeDiet2.2  ChimpanzeeDiet2.3  \
# ...
